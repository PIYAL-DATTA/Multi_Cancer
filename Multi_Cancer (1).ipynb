# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

import numpy as np

print("Using TensorFlow with DirectML compatibility")

# Create a very simple graph
a = tf.constant([1.0, 2.0, 3.0, 4.0])
b = tf.constant([2.0, 2.0, 2.0, 2.0])
c = a * b
d = tf.reduce_sum(c)

# Let TensorFlow choose the device automatically
with tf.Session() as sess:
    result = sess.run(d)
    print(f"Result: {result}")
    print("If this works, TensorFlow is automatically using DirectML")
# Out:
# WARNING:tensorflow:From C:\Users\Piyal\miniconda3\envs\tf-dml\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Using TensorFlow with DirectML compatibility
# Result: 20.0
# If this works, TensorFlow is automatically using DirectML

# %%
# !pip install tensorflow-directml
# Out:
# ...
#   Using cached numpy-1.18.5-cp37-cp37m-win_amd64.whl (12.7 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# ...

# %%
import tensorflow as tf
import numpy as np
import time

print("=== Final Confirmation Test ===")
print(f"TensorFlow version: {tf.__version__}")

# Test 1: Simple operations
print("\n1. Testing basic operations...")
a = tf.constant([[1.0, 2.0], [3.0, 4.0]])
b = tf.constant([[5.0, 6.0], [7.0, 8.0]])
c = a + b
d = tf.reduce_sum(c)

with tf.Session() as sess:
    result = sess.run(d)
    print(f"✓ Basic operations successful: {result}")

# Test 2: Matrix multiplication
print("\n2. Testing matrix multiplication...")
matrix1 = tf.constant(np.random.rand(100, 100).astype(np.float32))
matrix2 = tf.constant(np.random.rand(100, 100).astype(np.float32))
product = tf.matmul(matrix1, matrix2)

with tf.Session() as sess:
    start_time = time.time()
    result = sess.run(product)
    end_time = time.time()
    print(f"✓ Matrix multiplication successful!")
    print(f"  Shape: {result.shape}")
    print(f"  Time: {end_time - start_time:.4f} seconds")

# Test 3: Neural network layer
print("\n3. Testing neural network operations...")
inputs = tf.constant(np.random.rand(32, 64).astype(np.float32))
weights = tf.constant(np.random.rand(64, 32).astype(np.float32))
bias = tf.constant(np.random.rand(32).astype(np.float32))
output = tf.nn.relu(tf.matmul(inputs, weights) + bias)

with tf.Session() as sess:
    result = sess.run(output)
    print(f"✓ Neural network operations successful!")
    print(f"  Output shape: {result.shape}")

print("\n🎉 ALL TESTS PASSED! Your RX 6600 is fully operational with DirectML!")
print("   You can now use Jupyter Notebook for GPU-accelerated machine learning!")
# Out:
# === Final Confirmation Test ===
# TensorFlow version: 1.15.8
#
# 1. Testing basic operations...
# WARNING:tensorflow:From C:\Users\Piyal\AppData\Local\Temp\ipykernel_8508\717801330.py:15: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ✓ Basic operations successful: 36.0
#
# 2. Testing matrix multiplication...
# ✓ Matrix multiplication successful!
#   Shape: (100, 100)
#   Time: 0.0115 seconds
#
# 3. Testing neural network operations...
# ✓ Neural network operations successful!
#   Output shape: (32, 32)
#
# 🎉 ALL TESTS PASSED! Your RX 6600 is fully operational with DirectML!
#    You can now use Jupyter Notebook for GPU-accelerated machine learning!

# %%
import tensorflow as tf
import numpy as np

# Your RX 6600 will be automatically used for these operations
def create_model():
    # Simple neural network that will run on your GPU
    inputs = tf.placeholder(tf.float32, shape=[None, 784])
    labels = tf.placeholder(tf.float32, shape=[None, 10])
    
    # Hidden layer
    hidden = tf.layers.dense(inputs, 128, activation=tf.nn.relu)
    
    # Output layer
    logits = tf.layers.dense(hidden, 10)
    
    # Loss and optimizer
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits))
    optimizer = tf.train.AdamOptimizer().minimize(loss)
    
    return inputs, labels, loss, optimizer

# Example usage in a cell
print("Your RX 6600 is ready for machine learning in Jupyter!")
print("TensorFlow is automatically using DirectML for GPU acceleration.")
# Out:
# Your RX 6600 is ready for machine learning in Jupyter!
# TensorFlow is automatically using DirectML for GPU acceleration.

# %%
# Cell 1: Install required packages (run this first)
import sys
# !{sys.executable} -m pip install kagglehub tensorflow-directml matplotlib seaborn scikit-learn opencv-python pillow

print("All packages installed successfully!")
# Out:
# ...
# All packages installed successfully!
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# ...

# %%
# Cell 1: Install compatible packages
import sys
# !{sys.executable} -m pip install tensorflow-directml matplotlib seaborn scikit-learn opencv-python pillow requests urllib3==1.26.18

print("Packages installed successfully!")
# Out:
# ...
# Packages installed successfully!
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# ...

# %%
# Cell 1: Install only essential, compatible packages
import sys
# !{sys.executable} -m pip install tensorflow-directml matplotlib seaborn scikit-learn pillow --no-deps
# !{sys.executable} -m pip install --upgrade numpy

print("Essential packages installed!")
# Out:
# ...
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# ...

# %%
# Cell 4: Import libraries (using only what works in your environment)
import tensorflow as tf
import numpy as np
import os

print("TensorFlow version:", tf.__version__)
print("NumPy version:", np.__version__)

# Test GPU
print("\nGPU available:", tf.test.is_gpu_available())
print("GPU device name:", tf.test.gpu_device_name())
# Out:
# TensorFlow version: 1.15.8
# NumPy version: 1.21.6
#
# GPU available: True
# GPU device name: /device:DML:0

# %%
# Cell 2: Set up dataset path
import glob

dataset_path = r"C:\Users\Piyal\.cache\kagglehub\datasets\obulisainaren\multi-cancer\versions\3\Multi Cancer\Multi Cancer"

print("Checking dataset at:", dataset_path)

# Check what's in the dataset directory
if os.path.exists(dataset_path):
    items = os.listdir(dataset_path)
    print("Found in dataset directory:", items)
    
    # The actual data might be in a subdirectory called "Multi Cancer"
    possible_data_paths = [
        dataset_path,
        os.path.join(dataset_path, "Multi Cancer")
    ]
    
    data_dir = None
    for path in possible_data_paths:
        if os.path.exists(path):
            folders = os.listdir(path)
            cancer_folders = [f for f in folders if os.path.isdir(os.path.join(path, f))]
            if cancer_folders:
                print(f"✅ Found cancer data folders at: {path}")
                print(f"   Folders: {cancer_folders}")
                data_dir = path
                break
    
    if data_dir:
        # Count total images
        total_images = 0
        for folder in cancer_folders:
            folder_path = os.path.join(data_dir, folder)
            images = glob.glob(os.path.join(folder_path, "*.jpg")) + \
                    glob.glob(os.path.join(folder_path, "*.jpeg")) + \
                    glob.glob(os.path.join(folder_path, "*.png"))
            print(f"   {folder}: {len(images)} images")
            total_images += len(images)
        print(f"   Total images: {total_images}")
    else:
        print("❌ Could not find cancer data folders")
        data_dir = None
else:
    print("❌ Dataset path does not exist")
    data_dir = None
# Out:
# Checking dataset at: C:\Users\Piyal\.cache\kagglehub\datasets\obulisainaren\multi-cancer\versions\3\Multi Cancer\Multi Cancer
# Found in dataset directory: ['ALL', 'Brain Cancer', 'Breast Cancer', 'Cervical Cancer', 'Kidney Cancer', 'Lung and Colon Cancer', 'Lymphoma', 'Oral Cancer']
# ✅ Found cancer data folders at: C:\Users\Piyal\.cache\kagglehub\datasets\obulisainaren\multi-cancer\versions\3\Multi Cancer\Multi Cancer
#    Folders: ['ALL', 'Brain Cancer', 'Breast Cancer', 'Cervical Cancer', 'Kidney Cancer', 'Lung and Colon Cancer', 'Lymphoma', 'Oral Cancer']
#    ALL: 0 images
#    Brain Cancer: 0 images
#    Breast Cancer: 0 images
#    Cervical Cancer: 0 images
#    Kidney Cancer: 0 images
#    Lung and Colon Cancer: 0 images
#    Lymphoma: 0 images
#    Oral Cancer: 0 images
#    Total images: 0

# %%
# Cell 2: Set up dataset path with correct structure
dataset_path = r"C:\Users\Piyal\.cache\kagglehub\datasets\obulisainaren\multi-cancer\versions\3\Multi Cancer\Multi Cancer"

print("Checking dataset at:", dataset_path)

# Check what's in the dataset directory
if os.path.exists(dataset_path):
    cancer_types = os.listdir(dataset_path)
    print("Found cancer types:", cancer_types)

    # Define folders to exclude
    exclude_folders = [
        'all_benign', 'breast_benign', 'kidney_normal', 
        'colon_bnt', 'lung_bnt', 'oral_normal'
    ]
    
    # Count images recursively in each cancer type
    total_images = 0
    for cancer_type in cancer_types:
        cancer_path = os.path.join(dataset_path, cancer_type)
        if os.path.isdir(cancer_path):
            # Look for subdirectories within each cancer type
            subfolders = [f for f in os.listdir(cancer_path) if os.path.isdir(os.path.join(cancer_path, f))]
            
            # Filter out excluded folders
            filtered_subfolders = [folder for folder in subfolders if folder not in exclude_folders]
                        
            cancer_type_images = 0
            for subfolder in filtered_subfolders:
                subfolder_path = os.path.join(cancer_path, subfolder)
                # Count images in this subfolder
                images = (glob.glob(os.path.join(subfolder_path, "*.jpg")) + 
                         glob.glob(os.path.join(subfolder_path, "*.jpeg")) + 
                         glob.glob(os.path.join(subfolder_path, "*.png")))
                cancer_type_images += len(images)
            
            print(f"   {cancer_type}: {cancer_type_images} images (in {len(subfolders)} subfolders)")
            if subfolders:
                print(f"      Subfolders: {subfolders}")
            total_images += cancer_type_images
    
    print(f"   Total images: {total_images}")
    data_dir = dataset_path
else:
    print("❌ Dataset path does not exist")
    data_dir = None
# Out:
# Checking dataset at: C:\Users\Piyal\.cache\kagglehub\datasets\obulisainaren\multi-cancer\versions\3\Multi Cancer\Multi Cancer
# Found cancer types: ['ALL', 'Brain Cancer', 'Breast Cancer', 'Cervical Cancer', 'Kidney Cancer', 'Lung and Colon Cancer', 'Lymphoma', 'Oral Cancer']
#    ALL: 15000 images (in 4 subfolders)
#       Subfolders: ['all_benign', 'all_early', 'all_pre', 'all_pro']
#    Brain Cancer: 15000 images (in 3 subfolders)
#       Subfolders: ['brain_glioma', 'brain_menin', 'brain_tumor']
#    Breast Cancer: 5000 images (in 2 subfolders)
#       Subfolders: ['breast_benign', 'breast_malignant']
#    Cervical Cancer: 25000 images (in 5 subfolders)
#       Subfolders: ['cervix_dyk', 'cervix_koc', 'cervix_mep', 'cervix_pab', 'cervix_sfi']
#    Kidney Cancer: 5000 images (in 2 subfolders)
#       Subfolders: ['kidney_normal', 'kidney_tumor']
#    Lung and Colon Cancer: 15000 images (in 5 subfolders)
# ...

# %%
# Cell 3: Data preparation with TensorFlow
from tensorflow.keras.preprocessing.image import ImageDataGenerator

if data_dir:
    IMG_SIZE = (224, 224)
    BATCH = 16  # Good for your 6.85GB VRAM
    
    print(f"\nSetting up data generators from: {data_dir}")
    
    datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split=0.2,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True
    )
    
    train_gen = datagen.flow_from_directory(
        data_dir,
        target_size=IMG_SIZE,
        batch_size=BATCH,
        subset='training',
        class_mode='categorical'
    )
    
    val_gen = datagen.flow_from_directory(
        data_dir,
        target_size=IMG_SIZE,
        batch_size=BATCH,
        subset='validation',
        class_mode='categorical',
        shuffle=False  # Important for consistent validation
    )
    
    num_classes = len(train_gen.class_indices)
    class_names = list(train_gen.class_indices.keys())
    
    print(f"\n✅ Data loaded successfully!")
    print(f"Classes: {num_classes}")
    print(f"Class names: {class_names}")
    print(f"Training samples: {train_gen.samples}")
    print(f"Validation samples: {val_gen.samples}")
    print(f"Steps per epoch: {len(train_gen)}")
else:
    print("❌ Cannot set up data generators - data directory not found")
    train_gen, val_gen = None, None
    num_classes = 8
    class_names = []
# Out:
# Setting up data generators from: C:\Users\Piyal\.cache\kagglehub\datasets\obulisainaren\multi-cancer\versions\3\Multi Cancer\Multi Cancer
# Found 104002 images belonging to 8 classes.
# Found 26000 images belonging to 8 classes.
#
# ✅ Data loaded successfully!
# Classes: 8
# Class names: ['ALL', 'Brain Cancer', 'Breast Cancer', 'Cervical Cancer', 'Kidney Cancer', 'Lung and Colon Cancer', 'Lymphoma', 'Oral Cancer']
# Training samples: 104002
# Validation samples: 26000
# Steps per epoch: 6501

# %%
# Cell 4: Build an improved model
import tensorflow as tf
from tensorflow.keras import layers, models

def create_improved_cancer_model(input_shape=(224, 224, 3), num_classes=8):
    """Create an improved CNN model for cancer detection"""
    model = models.Sequential([
        # First conv block
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Second conv block  
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Third conv block
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Fourth conv block
        layers.Conv2D(256, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        
        # Fifth conv block
        layers.Conv2D(512, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.GlobalAveragePooling2D(),
        layers.Dropout(0.5),
        
        # Classifier
        layers.Dense(256, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    return model

# Create model
model = create_improved_cancer_model(num_classes=num_classes)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("Model created successfully!")
model.summary()
# Out:
# Model created successfully!
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 222, 222, 32)      128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 109, 109, 64)      256
# _________________________________________________________________
# ...

# %%
import sys
# Uninstall current version
# !{sys.executable} -m pip uninstall -y pillow

# Install a version compatible with TF 1.15
# !{sys.executable} -m pip install "Pillow<7.0.0"
# Out:
# Found existing installation: Pillow 6.2.2
# Uninstalling Pillow-6.2.2:
#   Successfully uninstalled Pillow-6.2.2
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# ERROR: Exception:
# ...

# %%
# Alternative data loading approach
# def load_and_preprocess_image(path):
#     image = tf.io.read_file(path)
#     image = tf.image.decode_image(image, channels=3)
#     image = tf.image.resize(image, [224, 224])
#     image = image / 255.0
#     return image

# %%
# import tensorflow as tf

# def custom_data_generator(image_paths, labels, batch_size=16):
#     def preprocess_path(path, label):
#         image = tf.io.read_file(path)
#         image = tf.image.decode_image(image, channels=3)
#         image = tf.image.resize(image, [224, 224])
#         image = image / 255.0
#         return image, label
    
#     dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
#     dataset = dataset.map(preprocess_path, num_parallel_calls=tf.data.AUTOTUNE)
#     dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    
#     return dataset

# %%
# Cell 5: Train the model
if train_gen and val_gen:
    print("🚀 Starting training with RX 6600 GPU...")
    print("This will use your GPU automatically via DirectML!")
    
    # Train for a few epochs first
    epochs_initial = 10
    steps_per_epoch = min(200, len(train_gen))  # Increased for better training
    validation_steps = min(50, len(val_gen))
    
    print(f"Training for {epochs_initial} epochs...")
    print(f"Steps per epoch: {steps_per_epoch}")
    print(f"Validation steps: {validation_steps}")
    
    # Add callbacks for better training
    callbacks = [
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7),
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    ]
    
    history = model.fit(
        train_gen,
        steps_per_epoch=steps_per_epoch,
        validation_data=val_gen,
        validation_steps=validation_steps,
        epochs=epochs_initial,
        callbacks=callbacks,
        verbose=1
    )
    
    print("✅ Initial training completed!")
else:
    print("❌ Cannot train - data generators not available")
    history = None
# Out:
# 🚀 Starting training with RX 6600 GPU...
# This will use your GPU automatically via DirectML!
# Training for 10 epochs...
# Steps per epoch: 200
# Validation steps: 50
# Epoch 1/10
# ...
# 200/200 [==============================] - 29s 147ms/step - loss: 0.2323 - acc: 0.9197 - val_loss: 0.0914 - val_acc: 0.9812
# Epoch 2/10
# ...
# 200/200 [==============================] - 28s 139ms/step - loss: 0.2106 - acc: 0.9334 - val_loss: 0.0062 - val_acc: 1.0000
# Epoch 3/10
# ...
# 200/200 [==============================] - 28s 139ms/step - loss: 0.1836 - acc: 0.9403 - val_loss: 2.6175 - val_acc: 0.0800
# Epoch 4/10
# ...
# 200/200 [==============================] - 28s 142ms/step - loss: 0.1628 - acc: 0.9503 - val_loss: 0.4653 - val_acc: 0.8200
# Epoch 5/10
# ...
# 200/200 [==============================] - 28s 139ms/step - loss: 0.1667 - acc: 0.9459 - val_loss: 0.0416 - val_acc: 0.9937
# Epoch 6/10
# ...

# %%
# Cell 6: Save the model
if train_gen:
    model.save('cancer_detection_model.h5')
    print("✅ Model saved as 'cancer_detection_model.h5'")
    
    # Also save class names for future use
    import json
    with open('class_names.json', 'w') as f:
        json.dump(class_names, f)
    print("✅ Class names saved as 'class_names.json'")
else:
    print("❌ No model to save")
# Out:
# ✅ Model saved as 'cancer_detection_model.h5'
# ✅ Class names saved as 'class_names.json'

# %%
# Cell 7: Evaluate the model
if val_gen and history:
    print("Evaluating model performance...")
    
    # Reset generator for consistent evaluation
    val_gen.reset()
    
    # Evaluate on validation set
    evaluation = model.evaluate(val_gen, steps=min(100, len(val_gen)))
    print(f"Validation Loss: {evaluation[0]:.4f}")
    print(f"Validation Accuracy: {evaluation[1]:.4f}")
    
    # Make predictions for confusion matrix
    print("\nGenerating predictions...")
    y_true = []
    y_pred = []
    
    for i in range(min(50, len(val_gen))):
        batch_x, batch_y = val_gen.next()
        batch_pred = model.predict(batch_x)
        
        true_labels = np.argmax(batch_y, axis=1)
        pred_labels = np.argmax(batch_pred, axis=1)
        
        y_true.extend(true_labels)
        y_pred.extend(pred_labels)
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    accuracy = np.mean(y_true == y_pred)
    print(f"Manual Accuracy Check: {accuracy:.4f}")
# Out:
# Evaluating model performance...
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0065 - acc: 1.0000
# Validation Loss: 0.0065
# Validation Accuracy: 1.0000
#
# Generating predictions...
# Manual Accuracy Check: 1.0000

# %%
import numpy as np
from sklearn.metrics import classification_report

# 1. Get the true labels (y_true)
# You need to know the total number of steps/samples in your validation set
# If steps_per_epoch was calculated as len(val_gen), use it here.
# A safe way is to reset the generator and grab all true labels.

# Reset generator to ensure labels are extracted from the start
val_gen.reset() 

# Extract true labels (y_true) from the generator
y_true = val_gen.classes[val_gen.index_array]
# Filter y_true to match the number of samples you actually predicted
# If you used the entire validation set:
# y_true = y_true[:val_gen.samples] 


# 2. Get predictions (y_pred_proba)
# Make predictions on the validation set using the generator
y_pred_proba = model.predict(
    val_gen, 
    steps=len(val_gen) # Ensure you predict on all batches
)

# 3. Convert probabilities to class indices (y_pred)
# Use argmax to get the index (0 to 7) of the highest probability
y_pred = np.argmax(y_pred_proba, axis=1)


# 4. Get target names and labels
target_names = list(val_gen.class_indices.keys())
# The labels parameter is necessary to tell classification_report which indices to expect (0 through 7)
labels = list(range(len(target_names)))


# 5. Print the report
print(classification_report(
    y_true, 
    y_pred, 
    labels=labels,        # Explicitly define the expected labels (0, 1, ..., 7)
    target_names=target_names
))
# Out:
#                        precision    recall  f1-score   support
#
#                   ALL       0.98      1.00      0.99      4000
#          Brain Cancer       1.00      1.00      1.00      3000
#         Breast Cancer       0.90      0.90      0.90      2000
#       Cervical Cancer       0.93      0.99      0.96      5000
#         Kidney Cancer       1.00      0.99      0.99      2000
# Lung and Colon Cancer       0.98      0.91      0.94      5000
#              Lymphoma       1.00      0.97      0.98      3000
#           Oral Cancer       0.85      0.88      0.86      2000
#
#              accuracy                           0.96     26000
#             macro avg       0.95      0.95      0.95     26000
#          weighted avg       0.96      0.96      0.96     26000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 6. Calculate the Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# 7. Plot the Confusion Matrix as a Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm, 
    annot=True,              # Show the counts in the cells
    fmt='d',                 # Format as integer counts
    cmap='Blues',            # Color map style
    xticklabels=class_names, # Use class names for x-axis
    yticklabels=class_names  # Use class names for y-axis
)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()

# If you need to save the plot:
# plt.savefig('confusion_matrix.png')

# %%
# Cell 8: Visualize training results
try:
    import matplotlib.pyplot as plt
    HAS_MATPLOTLIB = True
except ImportError:
    print("Install matplotlib for visualization: pip install matplotlib")
    HAS_MATPLOTLIB = False

if history and HAS_MATPLOTLIB:
    # Determine the correct key names for the current TF version
    history_dict = history.history
    
    # Check for 'accuracy' vs 'acc'
    if 'accuracy' in history_dict:
        acc_key = 'accuracy'
        val_acc_key = 'val_accuracy'
    else:
        acc_key = 'acc'
        val_acc_key = 'val_acc'
        
    print(f"Plotting using keys: {acc_key} and {val_acc_key}")

    # Plot training history
    plt.figure(figsize=(15, 5))
    
    # Plot Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history_dict[acc_key], label='Training Accuracy', marker='o')
    if val_acc_key in history_dict:
        plt.plot(history_dict[val_acc_key], label='Validation Accuracy', marker='o')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(history_dict['loss'], label='Training Loss', marker='o')
    if 'val_loss' in history_dict:
        plt.plot(history_dict['val_loss'], label='Validation Loss', marker='o')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig('training_history.png') # Save instead of just showing
    plt.show()
    
    print("📊 Training visualization completed!")
# Out:
# Plotting using keys: acc and val_acc
# 📊 Training visualization completed!

# %%
# Cell 9: Test predictions on sample images
if val_gen and HAS_MATPLOTLIB:
    # Get a batch of validation images
    val_images, val_labels = val_gen.next()
    predictions = model.predict(val_images)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = np.argmax(val_labels, axis=1)
    
    # Display sample predictions
    plt.figure(figsize=(20, 12))
    for i in range(8):
        plt.subplot(2, 4, i + 1)
        plt.imshow(val_images[i])
        
        true_label = class_names[true_classes[i]]
        pred_label = class_names[predicted_classes[i]]
        confidence = np.max(predictions[i])
        
        color = 'green' if true_label == pred_label else 'red'
        plt.title(f'True: {true_label}\nPred: {pred_label}\nConf: {confidence:.2f}', 
                  color=color, fontsize=12)
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()
    
    print("🎯 Sample predictions displayed!")
# Out:
# 🎯 Sample predictions displayed!

# %%
# Cell 10: Model performance summary
print("=" * 60)
print("CANCER DETECTION MODEL - PERFORMANCE SUMMARY")
print("=" * 60)

if train_gen:
    print(f"📁 Dataset: {data_dir}")
    print(f"🎯 Classes: {num_classes}")
    print(f"📊 Training samples: {train_gen.samples:,}")
    print(f"📊 Validation samples: {val_gen.samples:,}")
    print(f"🖼️  Image size: 224x224")
    print(f"📦 Batch size: {BATCH}")

if history:
    final_train_acc = history.history['acc'][-1]
    final_val_acc = history.history['val_accuracy'][-1] if 'val_accuracy' in history.history else 'N/A'
    final_train_loss = history.history['loss'][-1]
    final_val_loss = history.history['val_loss'][-1] if 'val_loss' in history.history else 'N/A'
    
    print(f"📈 Final Training Accuracy: {final_train_acc}")
    print(f"📈 Final Validation Accuracy: {final_val_acc}")
    print(f"📉 Final Training Loss: {final_train_loss}")
    print(f"📉 Final Validation Loss: {final_val_loss}")

print(f"💾 Model saved: cancer_detection_model.h5")
print(f"🖥️  GPU used: RX 6600 via DirectML")
print("=" * 60)
# Out:
# ...
# CANCER DETECTION MODEL - PERFORMANCE SUMMARY
# ...
# 📁 Dataset: C:\Users\Piyal\.cache\kagglehub\datasets\obulisainaren\multi-cancer\versions\3\Multi Cancer\Multi Cancer
# 🎯 Classes: 8
# 📊 Training samples: 104,002
# 📊 Validation samples: 26,000
# 🖼️  Image size: 224x224
# 📦 Batch size: 16
# 📈 Final Training Accuracy: 0.9671874642372131
# 📈 Final Validation Accuracy: N/A
# 📉 Final Training Loss: 0.1047899298730772
# 📉 Final Validation Loss: 0.009437849293462933
# 💾 Model saved: cancer_detection_model.h5
# 🖥️  GPU used: RX 6600 via DirectML
# ...

# %%
# # Cell 11: Continue training for better results (optional)
# if train_gen and val_gen:
#     print("🔄 Optional: Continue training for better accuracy...")
    
#     # Remove the input requirement and just continue training
#     print("Continuing training for 5 more epochs...")
    
#     history_continued = model.fit(
#         train_gen,
#         steps_per_epoch=min(200, len(train_gen)),
#         validation_data=val_gen,
#         validation_steps=min(50, len(val_gen)),
#         epochs=5,
#         verbose=1
#     )
    
#     # Update the model file
#     model.save('cancer_detection_model.h5')
#     print("✅ Additional training completed! Model updated.")
    
#     # Combine histories for plotting
#     if HAS_MATPLOTLIB and history:
#         # Combine the histories
#         combined_acc = history.history['acc'] + history_continued.history['acc']
#         combined_loss = history.history['loss'] + history_continued.history['loss']
        
#         # Handle validation metrics if they exist
#         combined_val_acc = []
#         combined_val_loss = []
        
#         if 'val_accuracy' in history.history:
#             combined_val_acc = history.history['val_accuracy'] + history_continued.history['val_accuracy']
#         if 'val_loss' in history.history:
#             combined_val_loss = history.history['val_loss'] + history_continued.history['val_loss']
        
#         plt.figure(figsize=(15, 5))
        
#         plt.subplot(1, 2, 1)
#         plt.plot(combined_acc, label='Training Accuracy')
#         if combined_val_acc:
#             plt.plot(combined_val_acc, label='Validation Accuracy')
#         plt.title('Combined Training History - Accuracy')
#         plt.xlabel('Epoch')
#         plt.ylabel('Accuracy')
#         plt.legend()
#         plt.grid(True)
        
#         plt.subplot(1, 2, 2)
#         plt.plot(combined_loss, label='Training Loss')
#         if combined_val_loss:
#             plt.plot(combined_val_loss, label='Validation Loss')
#         plt.title('Combined Training History - Loss')
#         plt.xlabel('Epoch')
#         plt.ylabel('Loss')
#         plt.legend()
#         plt.grid(True)
        
#         plt.tight_layout()
#         plt.show()

# %%
# !pip install efficientnet
# Out:
# ...
#   Using cached Pillow-9.5.0-cp37-cp37m-win_amd64.whl (2.5 MB)
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 6.2.2
#     Uninstalling Pillow-6.2.2:
#       Successfully uninstalled Pillow-6.2.2
# ...
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -llow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\piyal\miniconda3\envs\tf-dml\lib\site-packages)
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import efficientnet.tfkeras as efn 
import os

# --- Configuration ---
# 1. Provide the exact file name you downloaded
WEIGHTS_FILE = 'efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5'
NUM_CLASSES = 8 # Assuming 8 classes as per your original code

# Check if the file exists (Optional but helpful check)
if not os.path.exists(WEIGHTS_FILE):
    # This print statement will run if the file is not in the notebook's directory
    print(f"\n🛑 ERROR: Weights file not found! Please ensure '{WEIGHTS_FILE}' is in the same folder as this notebook.")
else:
    print(f"✅ Found weights file: {WEIGHTS_FILE}. Loading model...")
    
    # 2. Use the local file path instead of 'imagenet'
    base = efn.EfficientNetB0(weights=WEIGHTS_FILE, include_top=False,
                              input_shape=(224,224,3))
    base.trainable = False

    inputs = layers.Input(shape=(224,224,3))
    x = base(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x) 

    model = models.Model(inputs, outputs)

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()
# Out:
# ✅ Found weights file: efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5. Loading model...
# WARNING:tensorflow:From C:\Users\Piyal\miniconda3\envs\tf-dml\lib\site-packages\tensorflow_core\python\util\deprecation.py:507: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnet-b0 (Model)      (None, 7, 7, 1280)        4049564
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1280)              0
# ...

# %%
# history = model.fit(
#     train_gen,
#     validation_data=val_gen,
#     epochs=10
# )

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10
)
# Out:
# Epoch 1/10
# ...
# 6501/6501 [==============================] - 972s 150ms/step - loss: 0.0764 - acc: 0.9777 - val_loss: 0.0953 - val_acc: 0.9683
# Epoch 2/10
# ...
# 6501/6501 [==============================] - 1035s 159ms/step - loss: 0.0348 - acc: 0.9880 - val_loss: 0.0948 - val_acc: 0.9683
# Epoch 3/10
# ...
# 6501/6501 [==============================] - 1047s 161ms/step - loss: 0.0320 - acc: 0.9883 - val_loss: 0.0870 - val_acc: 0.9710
# Epoch 4/10
# ...
# 6501/6501 [==============================] - 1046s 161ms/step - loss: 0.0312 - acc: 0.9888 - val_loss: 0.0693 - val_acc: 0.9778
# Epoch 5/10
# ...
# 6501/6501 [==============================] - 1047s 161ms/step - loss: 0.0307 - acc: 0.9887 - val_loss: 0.0677 - val_acc: 0.9781
# Epoch 6/10
# ...
# 6501/6501 [==============================] - 1049s 161ms/step - loss: 0.0307 - acc: 0.9886 - val_loss: 0.1089 - val_acc: 0.9670
# Epoch 7/10
# ...
# 6501/6501 [==============================] - 1046s 161ms/step - loss: 0.0304 - acc: 0.9890 - val_loss: 0.0995 - val_acc: 0.9700
# ...

# %%
base.trainable = True

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

history_fine = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=10
)
# Out:
# Epoch 1/10
# ...
# 6501/6501 [==============================] - 1478s 227ms/step - loss: 0.0101 - acc: 0.9965 - val_loss: 0.0555 - val_acc: 0.9862
# Epoch 2/10
# ...
# 6501/6501 [==============================] - 1474s 227ms/step - loss: 0.0035 - acc: 0.9988 - val_loss: 0.1533 - val_acc: 0.9684
# Epoch 3/10
# ...
# 6501/6501 [==============================] - 1477s 227ms/step - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0460 - val_acc: 0.9890
# Epoch 4/10
# ...
# 6501/6501 [==============================] - 1475s 227ms/step - loss: 0.0015 - acc: 0.9996 - val_loss: 0.1193 - val_acc: 0.9763
# Epoch 5/10
# ...
# 6501/6501 [==============================] - 1474s 227ms/step - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0469 - val_acc: 0.9883
# Epoch 6/10
# ...
# 6501/6501 [==============================] - 1460s 225ms/step - loss: 0.0011 - acc: 0.9997 - val_loss: 0.0637 - val_acc: 0.9868
# Epoch 7/10
# ...

# %%
import numpy as np
from sklearn.metrics import classification_report

# 1. Get the true labels (y_true)
# You need to know the total number of steps/samples in your validation set
# If steps_per_epoch was calculated as len(val_gen), use it here.
# A safe way is to reset the generator and grab all true labels.

# Reset generator to ensure labels are extracted from the start
val_gen.reset() 

# Extract true labels (y_true) from the generator
y_true = val_gen.classes[val_gen.index_array]
# Filter y_true to match the number of samples you actually predicted
# If you used the entire validation set:
# y_true = y_true[:val_gen.samples] 


# 2. Get predictions (y_pred_proba)
# Make predictions on the validation set using the generator
y_pred_proba = model.predict(
    val_gen, 
    steps=len(val_gen) # Ensure you predict on all batches
)

# 3. Convert probabilities to class indices (y_pred)
# Use argmax to get the index (0 to 7) of the highest probability
y_pred = np.argmax(y_pred_proba, axis=1)


# 4. Get target names and labels
target_names = list(val_gen.class_indices.keys())
# The labels parameter is necessary to tell classification_report which indices to expect (0 through 7)
labels = list(range(len(target_names)))


# 5. Print the report
print(classification_report(
    y_true, 
    y_pred, 
    labels=labels,        # Explicitly define the expected labels (0, 1, ..., 7)
    target_names=target_names
))
# Out:
#                        precision    recall  f1-score   support
#
#                   ALL       1.00      1.00      1.00      4000
#          Brain Cancer       1.00      1.00      1.00      3000
#         Breast Cancer       0.96      1.00      0.98      2000
#       Cervical Cancer       1.00      1.00      1.00      5000
#         Kidney Cancer       1.00      1.00      1.00      2000
# Lung and Colon Cancer       1.00      0.94      0.97      5000
#              Lymphoma       1.00      1.00      1.00      3000
#           Oral Cancer       0.90      1.00      0.95      2000
#
#              accuracy                           0.99     26000
#             macro avg       0.98      0.99      0.99     26000
#          weighted avg       0.99      0.99      0.99     26000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 6. Calculate the Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# 7. Plot the Confusion Matrix as a Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm, 
    annot=True,              # Show the counts in the cells
    fmt='d',                 # Format as integer counts
    cmap='Blues',            # Color map style
    xticklabels=class_names, # Use class names for x-axis
    yticklabels=class_names  # Use class names for y-axis
)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()

# If you need to save the plot:
# plt.savefig('confusion_matrix.png')
